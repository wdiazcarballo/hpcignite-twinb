# %% [markdown]
# # Data loading

# %%
print("Hello Jupyter")
# Out:
# Hello Jupyter

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

print("numpy:", np.__version__)
print("pandas:", pd.__version__)
print("matplotlib:", matplotlib.__version__)
print("seaborn:", sns.__version__)
# Out:
# numpy: 2.2.6
# pandas: 2.3.1
# matplotlib: 3.10.5
# seaborn: 0.13.2

# %%
df = pd.read_csv("mesa_agent_results.csv")
df.head()
# Out:
#    step  agent_id agent_type       room  current_temp  comfort_level using_ac  \
# 0     0        37    student  East Zone         45.57          19.75     True
# 1     0        66    student  East Zone         45.57          21.51     True
# 2     0        95    student  East Zone         45.57          20.20     True
# 3     0        65    student  West Zone         23.04           1.85    False
# 4     0         1    student  West Zone         23.04           2.74    False
#
#    preferred_temp action
# 0           25.82    NaN
# 1           24.06    NaN
# 2           25.37    NaN
# 3           24.89    NaN
# 4           25.78    NaN

# %%
df.isnull().sum()
# Out:
# step                   0
# agent_id               0
# agent_type             0
# room                   0
# current_temp           0
# comfort_level       1600
# using_ac            1600
# preferred_temp         0
# action            112000
# dtype: int64

# %%
df['comfort_level'] = df['comfort_level'].fillna(0)

# %%
df.dtypes
# Out:
# step                int64
# agent_id            int64
# agent_type         object
# room               object
# current_temp      float64
# comfort_level     float64
# using_ac           object
# preferred_temp    float64
# action             object
# dtype: object

# %%
df.describe()
# Out:
#                 step       agent_id   current_temp  comfort_level  \
# count  113600.000000  113600.000000  113600.000000  113600.000000
# mean       99.500000      70.500000      35.292865      11.482912
# std        57.734559      40.991033      11.635891       9.969037
# min         0.000000       0.000000      23.000000       0.000000
# 25%        49.750000      35.000000      23.660000       1.620000
# 50%        99.500000      70.500000      44.710000       4.210000
# 75%       149.250000     106.000000      46.550000      21.220000
# max       199.000000     141.000000      50.310000      26.300000
#
#        preferred_temp
# count   113600.000000
# mean        25.355528
# std          0.832876
# min         24.010000
# 25%         24.720000
# 50%         25.310000
# 75%         25.830000
# max         27.970000

# %% [markdown]
# # Analysis

# %%
avg_comfort = df.groupby("step")["comfort_level"].mean()
plt.figure(figsize=(10,5))
plt.plot(avg_comfort.index, avg_comfort.values, marker="o")
plt.xlabel("Step")
plt.ylabel("Average Comfort Level")
plt.title("Average Comfort per Step")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["preferred_temp"].to_numpy(), bins=15, edgecolor="black")
plt.xlabel("Preferred Temp (°C)")
plt.ylabel("Count")
plt.title("Distribution of Preferred Temperature")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8,5))
df.boxplot(column="comfort_level", by="using_ac")
plt.title("Comfort Level by AC Usage")
plt.suptitle("")
plt.xlabel("Using AC")
plt.ylabel("Comfort Level")
plt.show()

# %%
ac_usage = df.groupby("step")["using_ac"].sum()  # จำนวน agent ที่เปิด AC
plt.figure(figsize=(10,5))
plt.plot(ac_usage.index, ac_usage.values, marker="o", color="orange")
plt.xlabel("Step")
plt.ylabel("Number of Agents Using AC")
plt.title("AC Usage per Step")
plt.grid(True)
plt.show()
